# %% [markdown]
# # 3_modeling_evaluation_suto

# %%
import os

# Biblioteca built-in para obtenção de combinações
from itertools import combinations

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import PolynomialFeatures

# Bibliotecas de modelos
from pycaret.regression import * 
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import (cross_val_score, RepeatedStratifiedKFold,
                                     RandomizedSearchCV, GridSearchCV, train_test_split)

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

path_data = "../data/raw/"
path_interim_data = "../data/interim/"

# Parâmetros estéticos dos gráficos:
set_palette = "Paired"
axes_style = "ticks"

linha = 50*"-"

# %%
df_data = pd.read_parquet(path_interim_data+"df_data_step_2_output.pqt")

print(f"Dimensões do dataset: {df_data.shape}")

df_data.head()
# Out:
# Dimensões do dataset: (397, 6)
#    displacement  horsepower  weight  acceleration  origin   mpg
# 0         360.0       175.0  3821.0          11.0     1.0  13.0
# 1         390.0       190.0  3850.0           8.5     1.0  15.0
# 2         304.0       150.0  3672.0          11.5     1.0  17.0
# 3         232.0        90.0  3210.0          17.2     1.0  19.4
# 4         151.0        90.0  3003.0          20.1     1.0  24.3

# %% [markdown]
# ### Preparação do conjunto de dados
#
# Antes de submetermos o **conjunto de dados de treinamento** aos diferentes modelos e avaliarmos os modelos treinados com **o conjunto de dados de validação**, faremos os passos abaixo:
#
# 1. Selecionarmos apenas os atributos contínuos; e
# 1. Separarmos o conjunto de dados em treinamento e validação.

# %%
# Limitando a análise apenas aos fatores contínuos
ls_continuous_features = df_data.select_dtypes(include=[float]).columns
ls_continuous_features = sorted(ls_continuous_features)

lst_continuas_sem_mpg = [feature for feature in ls_continuous_features if feature not in ['mpg', 'origin']]


# Separando em conjunto de treinamento e validação
X = df_data[lst_continuas_sem_mpg]
y = df_data["mpg"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.1, random_state=42)

# %% [markdown]
# ## Regressão linear simples
#
# Verificando a relação de cada fator/variável de entrada/preditor contínuo sobre a resposta/variável de saída.
#
# **IMPORTANTE**: nesse momento, estamos apenas avaliando os fatores contínuos.

# %%
def create_linspace_df(df, features_list=[None], elements_number=100):
    """
    O objetivo desta função é criar um dataframe com uma quantidade de registros igualmente espaçados,
    indicado para usar em regressão.
    
    Inputs:
        df: DataFrame do qual deseja-se criar o domínio igualmente espaçado.
        features_list: lista com as variáveis nu
        elements_number: 100
    
    Output:
        df_result: DataFrame
    """
    import pandas as pd
    
    if features_list[0]==None:
        features_list = df.select_dtypes(include=[float, "float32", "float64"]).columns
    else:
        pass
    
    df_result = pd.DataFrame()
    
    for feature in features_list:
        min_temp = int(df[feature].min()*.95)
        max_temp = int(df[feature].max()*1.05)
        df_result[feature] = np.linspace(min_temp, max_temp, num=elements_number, endpoint=True)
        
    return df_result

# %%
# Criando um dataset com valores de X igualmente espaçados para gerar as retas.
df_reg = create_linspace_df(df_data, features_list=lst_continuas_sem_mpg)

# Obtendo as equações de reta para cada relação "fator vs 'mpg'".
dct_equations = {}

for feature in df_data[lst_continuas_sem_mpg].columns:
    model = LinearRegression()
    model.fit(X_train[feature].values.reshape(-1, 1), y_train)
    dct_equations[feature] = "y = " + str(round(model.intercept_, 2)) + " + (" + str(round(model.coef_[0], 2)) + "*x)"
    df_reg["y_pred_mpg_"+feature] = model.predict(df_reg[feature].values.reshape(-1, 1))
    
print(f"Dimensão da matriz: {df_reg.shape}")
# Out:
# Dimensão da matriz: (100, 8)

# %% [markdown]
# **Plotando regressões lineares simples**
#
# Abaixo plotaremos as quatro regressões lineares simples a partir da relação entre os pares de fatores contínuos e a resposta.
# - acceleration vs mpg
# - displacement vs mpg
# - horsepower vs mpg
# - weight vs mpg

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(15,12), sharey=True, gridspec_kw={'hspace': .35, 'wspace': .1})

row = col = 0

for i, feature in enumerate(df_data[lst_continuas_sem_mpg].columns):
    axs[row, col].scatter(data=df_data, x=feature, y="mpg")
    axs[row, col].plot(df_reg[feature], df_reg["y_pred_mpg_"+feature], color='red')
    axs[row, col].set_title("Regressão linear simples de\n'"+feature+"' vs 'mpg'",
                            fontdict={'fontsize':14}, pad=12)
    axs[row, col].set(ylim=[0,50], xlabel=feature);
            
    textstr = f""" Equação da reta: \n{dct_equations[feature]}"""

    props = dict(boxstyle='round', facecolor='wheat', alpha=0.25)
    
    axs[row, col].text(.65, 0.96, textstr, transform=axs[row, col].transAxes, fontsize=12,
        verticalalignment='top', bbox=props, color='red');

    if (i+1)%2!=0:
        col += 1
    else:
        col = 0
        row += 1
        
for ax in axs.flat:
    ax.set(ylabel='mpg')

# %% [markdown]
# ### Avaliando os modelos obtidos
#
# Para cada modelo de regressão linear obtido, avaliaremos utilizando duas métricas:
# - R²
# - RMSE (Raiz do erro quadrático médio)

# %%
dct_metrics = {}

for feature in df_data[lst_continuas_sem_mpg].columns:
    model = LinearRegression()
    model.fit(X_train[feature].values.reshape(-1, 1), y_train)
    y_pred = model.predict(X_test[feature].values.reshape(-1, 1))
    dct_metrics[len(dct_metrics)] = {"Model": "Simple Linear Regression",
                                     "Features": feature,
                                     "R²": r2_score(y_test, y_pred),
                                     "RMSE": mean_squared_error(y_test, y_pred)**.5}
    
pd.DataFrame.from_dict(dct_metrics, orient="index").sort_values(by="RMSE")
# Out:
#                       Model      Features        R²      RMSE
# 2  Simple Linear Regression    horsepower  0.657818  4.623190
# 3  Simple Linear Regression        weight  0.645245  4.707361
# 1  Simple Linear Regression  displacement  0.546235  5.323883
# 0  Simple Linear Regression  acceleration  0.203712  7.052580

# %% [markdown]
# ### Comentários sobre os resultados da regressão linear simples
#
# Ao avaliarmos a tabela contendo as métricas R² e RMSE, vemos que o fator *'horsepower'* apresentou melhores resultados (menor RMSE e maior R²) que os outros três pares.
#
# Na seção a seguir, veremos o como seria o cenário se tivermos mais de dois fatores.

# %% [markdown]
# ## Regressão polinomial
#
# Será que se adicionarmos fatores com graus diferentes (maiores que 1) as métricas de avaliação melhoram?
#
# Faremos os seguintes passos:
#
# 1. Polinômio de grau 2
#
#  $$ y(x) = \beta_{0} + \beta_{1}x + \beta_{2}x^2 $$
#
#
# 2. Polinômio de grau 2 mais fatores de interação entre os fatores.
#  - Essa já é considerada uma regressão linear múltipla =)
#
#  $$ y(x_{0}, x_{1}) = \beta_{0} + \beta_{1}x_{0} + \beta_{2}x_{1} + \beta_{3}x_{0}^2 + \beta_{4}x_{0}x_{1} + \beta_{5}x_{1}^2$$
#
#
#
# ### Regressão polinomial - Polinômio de grau 2

# %%
# Criando um dataset com valores de X igualmente espaçados para gerar as retas.
df_reg_poly = create_linspace_df(df_data, features_list=lst_continuas_sem_mpg)

# Obtendo as equações de reta para cada relação "fator vs 'mpg'".
dct_equations_poly = {}

for feature in df_data[lst_continuas_sem_mpg].columns:
    X_poly = PolynomialFeatures(degree=2, include_bias=False)
    X_train_poly = X_poly.fit_transform(X_train[feature].values.reshape(-1, 1))
    model = LinearRegression()
    model.fit(X_train_poly, y_train)
    dct_equations_poly[feature] = (str(round(model.intercept_, 6)) +
                                   " + (" + str(round(model.coef_[-2], 6)) + "*x)"
                                   " + (" + str(round(model.coef_[-1], 6)) + "*x²)")
#                                    " + (" + str(model.coef_[-2]) + "*x)"
#                                    " + (" + str(model.coef_[-1]) + "*x²)")
    
    X_poly = PolynomialFeatures(degree=2, include_bias=False)
    X_reg_poly = X_poly.fit_transform(df_reg_poly[feature].values.reshape(-1, 1))
    df_reg_poly["y_pred_mpg_"+feature] = model.predict(X_reg_poly)

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(15,12), sharey=True, gridspec_kw={'hspace': .35, 'wspace': .1})

row = col = 0

for i, feature in enumerate(df_data[lst_continuas_sem_mpg].columns):
    axs[row, col].scatter(data=df_data, x=feature, y="mpg")
    axs[row, col].plot(df_reg_poly[feature], df_reg_poly["y_pred_mpg_"+feature], color='red')
    axs[row, col].set_title("Regressão polinomial de grau 2 de\n'"+feature+"' vs 'mpg'",
                            fontdict={'fontsize':14}, pad=12)
    axs[row, col].set(ylim=[0,50], xlabel=feature);
            
    textstr = f""" Equação da reta: \n{dct_equations_poly[feature]}"""

    props = dict(boxstyle='round', facecolor='wheat', alpha=0.25)
    
    axs[row, col].text(.02, 0.98, textstr, transform=axs[row, col].transAxes, fontsize=12,
        verticalalignment='top', horizontalalignment='left', bbox=props, color='red');

    if (i+1)%2!=0:
        col += 1
    else:
        col = 0
        row += 1
        
for ax in axs.flat:
    ax.set(ylabel='mpg')

# %%
for feature in df_data[lst_continuas_sem_mpg].columns:
    X_poly = PolynomialFeatures(degree=2, include_bias=False)
    X_train_poly = X_poly.fit_transform(X_train[feature].values.reshape(-1, 1))
    model = LinearRegression()
    model.fit(X_train_poly, y_train)
    X_test_poly = X_poly.fit_transform(X_test[feature].values.reshape(-1, 1))
    y_pred = model.predict(X_test_poly)
    dct_metrics[len(dct_metrics)] = {"Model": "Polynomial regression - degree=2",
                                     "Features": feature,
                                     "R²": r2_score(y_test, y_pred),
                                     "RMSE": mean_squared_error(y_test, y_pred)**.5}

pd.DataFrame.from_dict(dct_metrics, orient='index').sort_values(by="RMSE", ascending=True)
# Out:
#                               Model      Features        R²      RMSE
# 6  Polynomial regression - degree=2    horsepower  0.767622  3.809873
# 2          Simple Linear Regression    horsepower  0.657818  4.623190
# 7  Polynomial regression - degree=2        weight  0.653018  4.655499
# 3          Simple Linear Regression        weight  0.645245  4.707361
# 5  Polynomial regression - degree=2  displacement  0.575421  5.149822
# 1          Simple Linear Regression  displacement  0.546235  5.323883
# 4  Polynomial regression - degree=2  acceleration  0.237576  6.900988
# 0          Simple Linear Regression  acceleration  0.203712  7.052580

# %% [markdown]
# ### Regressão polinomial - Polinômio de grau 2 mais fatores de interação (produtos dos fatores principais)
#
# Nesse exemplo, testaremos combinações dos 4 fatores principais tomados dois a dois. E, portanto, teremos 6 combinações dos fatores principais:
#
# $$ C_{2}^4 = \binom{4}{2} = \frac{4!}{(4-2)! * 2!} = 6$$
#
# - 'acceleration'*'displacement'
# - 'acceleration'*'horsepower'
# - 'acceleration'*'weight'
# - 'displacement'*'horsepower'
# - 'displacement'*'weight'
# - 'horsepower'*'weight'

# %%
# Construção dos pares de atributos combinados 2 a 2.
combination = combinations(df_data[lst_continuas_sem_mpg].columns, 2)

feature_combinations = []

for pair in combination: 
    feature_combinations.append(list(pair))

# %%
# Criando um dataset com valores de X igualmente espaçados para gerar as retas.
df_reg_poly = create_linspace_df(df_data, features_list=lst_continuas_sem_mpg)

# Obtendo as equações de reta para cada relação "fator vs 'mpg'".
dct_equations_poly_interaction = {}

for feature_pair in feature_combinations:
    X_poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
    X_train_poly = X_poly.fit_transform(X_train[feature_pair])
    model = LinearRegression()
    model.fit(X_train_poly, y_train)
    dct_equations_poly_interaction[str(feature_pair)] = (str(round(model.intercept_, 6)) +
                                                         " + (" + str(round(model.coef_[0], 6)) + "*x0)"
                                                         " + (" + str(round(model.coef_[1], 6)) + "*x1)"
                                                         " + (" + str(round(model.coef_[2], 6)) + "*x0^2)"
                                                         " + (" + str(round(model.coef_[3], 6)) + "*x0x1)"
                                                         " + (" + str(round(model.coef_[4], 6)) + "*x1^2)")
    
    X_poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
    X_reg_poly = X_poly.fit_transform(df_reg_poly[feature_pair])
    df_reg_poly["y_pred_mpg_"+str(feature_pair)] = model.predict(X_reg_poly)

# %%
for feature_pair in feature_combinations:
    X_poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
    X_train_poly = X_poly.fit_transform(X_train[feature_pair])
    model = LinearRegression()
    model.fit(X_train_poly, y_train)
    X_test_poly = X_poly.fit_transform(X_test[feature_pair])
    y_pred = model.predict(X_test_poly)
    dct_metrics[len(dct_metrics)] = {"Model": "Polynomial regression with interactions - degree=2",
                                     "Features": str(feature_pair),
                                     "R²": r2_score(y_test, y_pred),
                                     "RMSE": mean_squared_error(y_test, y_pred)**.5}

pd.DataFrame.from_dict(dct_metrics, orient='index').sort_values(by="RMSE", ascending=True)
# Out:
#                                                 Model  \
# 6                    Polynomial regression - degree=2
# 9   Polynomial regression with interactions - degr...
# 13  Polynomial regression with interactions - degr...
# 11  Polynomial regression with interactions - degr...
# 12  Polynomial regression with interactions - degr...
# 10  Polynomial regression with interactions - degr...
# 2                            Simple Linear Regression
# 7                    Polynomial regression - degree=2
# 3                            Simple Linear Regression
# 5                    Polynomial regression - degree=2
# 8   Polynomial regression with interactions - degr...
# 1                            Simple Linear Regression
# 4                    Polynomial regression - degree=2
# 0                            Simple Linear Regression
#
#                             Features        R²      RMSE
# 6                         horsepower  0.767622  3.809873
# 9     ['acceleration', 'horsepower']  0.756150  3.902787
# 13          ['horsepower', 'weight']  0.736056  4.060399
# 11    ['displacement', 'horsepower']  0.694149  4.370873
# 12        ['displacement', 'weight']  0.665898  4.568280
# 10        ['acceleration', 'weight']  0.663343  4.585711
# 2                         horsepower  0.657818  4.623190
# 7                             weight  0.653018  4.655499
# 3                             weight  0.645245  4.707361
# 5                       displacement  0.575421  5.149822
# 8   ['acceleration', 'displacement']  0.567776  5.195980
# 1                       displacement  0.546235  5.323883
# 4                       acceleration  0.237576  6.900988
# 0                       acceleration  0.203712  7.052580

# %% [markdown]
#  ## Regressão linear múltipla
#
# Verificando o impacto de dois ou mais fatores/variáveis de entrada sobre a reposta/variável de saída.

# %%
X = df_data[lst_continuas_sem_mpg]
y = df_data["mpg"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.1, random_state=42)

model = LinearRegression()

model.fit(X_train, y_train);

# %%
cv = 3
scoring = "neg_root_mean_squared_error"
# "neg_mean_squared_error", "r2"

n_scores = cross_val_score(model, X_train, y_train, scoring=scoring, cv=cv, n_jobs=-1, error_score='raise')

print(f"MSE: média: {n_scores.mean():.3f}, desvio padrão: {n_scores.std():.3f}")
# Out:
# MSE: média: -4.247, desvio padrão: 0.354

# %%
y_pred = model.predict(X_test)

# %%
sns.set_palette(set_palette)
sns.axes_style(axes_style)

ax = sns.scatterplot(x=X_test["weight"].values, y=y_pred)

# %% [markdown]
# ## Bônus: Testando um vários modelos de regressão usando o PyCaret

# %%
regression = setup(data = df_data[ls_continuous_features].drop("origin", axis=1),
                   target = "mpg")

best = compare_models(sort = 'MSE')
# Out:
# <style  type="text/css" >
#     #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2 th {
#           text-align: left;
#     }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row0_col0 {
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row0_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row1_col0 {
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row1_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row1_col4 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row1_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row1_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row1_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row2_col0 {
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row2_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row3_col0 {
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row3_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row4_col0 {
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row4_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row5_col0 {
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row5_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row6_col0 {
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row6_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row7_col0 {
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row7_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row8_col0 {
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_5ccd5b98ebf2row8_col4 {
#             : ;
#             text-align:  left;
#         }    #T_a6a3c116_0f4d_11eb_b0d4_
